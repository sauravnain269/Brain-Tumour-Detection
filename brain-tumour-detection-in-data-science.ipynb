# %% [markdown]
# # Import Statements

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data list for storing image data in numpy array form
# 2. paths list for storing paths of all images
# 3. result list for storing one hot encoded form of target class whether normal or tumor

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'../input/brain-mri-images-for-brain-tumor-detection/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../input/brain-mri-images-for-brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               33554944
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 3s 1s/step - loss: 91.0058 - val_loss: 66.3344
# Epoch 2/30
# 3/3 [==============================] - 3s 1s/step - loss: 18.7273 - val_loss: 74.5017
# Epoch 3/30
# 3/3 [==============================] - 3s 1s/step - loss: 13.6022 - val_loss: 26.9026
# Epoch 4/30
# 3/3 [==============================] - 3s 993ms/step - loss: 2.4781 - val_loss: 9.4409
# Epoch 5/30
# 3/3 [==============================] - 3s 1s/step - loss: 2.5413 - val_loss: 12.4309
# Epoch 6/30
# 3/3 [==============================] - 3s 1s/step - loss: 2.3853 - val_loss: 12.0220
# Epoch 7/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.9295 - val_loss: 7.1852
# Epoch 8/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.5981 - val_loss: 3.2778
# Epoch 9/30
# 3/3 [==============================] - 3s 997ms/step - loss: 0.4711 - val_loss: 2.0764
# Epoch 10/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.4375 - val_loss: 2.2336
# Epoch 11/30
# 3/3 [==============================] - 3s 991ms/step - loss: 0.2064 - val_loss: 1.4817
# Epoch 12/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1056 - val_loss: 1.3537
# Epoch 13/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1183 - val_loss: 1.6246
# Epoch 14/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1270 - val_loss: 1.8556
# Epoch 15/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1360 - val_loss: 1.9810
# Epoch 16/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1070 - val_loss: 1.9497
# Epoch 17/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0774 - val_loss: 1.8623
# Epoch 18/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0749 - val_loss: 1.7302
# Epoch 19/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0572 - val_loss: 1.6130
# Epoch 20/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0351 - val_loss: 1.5387
# Epoch 21/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0340 - val_loss: 1.5041
# Epoch 22/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0273 - val_loss: 1.4908
# Epoch 23/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0507 - val_loss: 1.4901
# Epoch 24/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0396 - val_loss: 1.4960
# Epoch 25/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0259 - val_loss: 1.5119
# Epoch 26/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0197 - val_loss: 1.5220
# Epoch 27/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0155 - val_loss: 1.5260
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1740 - val_loss: 1.4639
# Epoch 29/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0114 - val_loss: 1.3221
# Epoch 30/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0217 - val_loss: 1.2188

# %% [markdown]
# # Plotting Losses

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Just Checking the Model

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
